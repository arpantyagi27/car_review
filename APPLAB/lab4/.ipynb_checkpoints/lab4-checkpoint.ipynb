# %%
#set2 ques3
from tkinter import *
root=Tk()
root.geometry("1310x650")
mainheader=Label(root,text="REGISTRATION INFORMATION",font=('Helvetica', 18, 'bold'),bg="grey",borderwidth=1, relief="solid").grid(row=0,column=1,columnspan=2)
reg1=Label(root,text="Registration Period(check one)").grid(row=1,column=0 )
reg2=Checkbutton(root,text="One Year").grid(row=1,column=1 )
reg3=Checkbutton(root,text="Two Years($2 discount applies)").grid(row=1,column=2 )
reg4=Checkbutton(root,text="Three Years($3 discount applies)").grid(row=1,column=3)
reg6=Label(root,text="Registration Type(check one)").grid(row=2,column=0 )
reg7=Checkbutton(root,text="Original").grid(row=2,column=1 )
reg8=Checkbutton(root,text="Private").grid(row=2,column=2 )
reg9=Checkbutton(root,text="Reissue(plates & decals)").grid(row=2,column=3 )
reg10=Checkbutton(root,text="Reissue (Decals only)").grid(row=3,column=0 )
reg11=Checkbutton(root,text="Rental Vehicle").grid(row=3,column=1 )
reg12=Checkbutton(root,text="Transfer License Plate Number").grid(row=3,column=2 )
reg13=Label(root,text="ENTER PLATE NUMBER").grid(row=3,column=3 )
e1=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=3,column=4 )
reg14=Checkbutton(root,text="For Hire(complete 'For Hire Information' sector)").grid(row=4,column=0 )
reg15=Checkbutton(root,text="Ridesharing(Varpool)(Cannot exceed 16 passenger including Driver)").grid(row=4,column=1,columnspan=2 )
reg16=Label(root,text="Seating Capacity").grid(row=4,column=3 )
e2=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=4,column=4 )
reg17=Checkbutton(root,text="Amateur Radio Operation Call Letters-Specify Letters",width=40).grid(row=5,column=0 )
e3=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=5,column=1 )
reg18=Checkbutton(root,text="Other").grid(row=5,column=2 )
reg19=Label(root,text="Specify").grid(row=5,column=3 )
e4=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=5,column=4 )
mainheader1=Label(root,text="OWNER INFORMATION",font=('Helvetica', 18, 'bold'),borderwidth=1, relief="solid",bg="grey").grid(row=6,column=1,columnspan=2)
reg20=Label(root,text="OWNER'S FULL LEGAL NAME (last,first,mi,suffix) OR BUSINESS NAME",width=67).grid(row=7,column=0 )
e5=Entry(root,width=67,highlightbackground="black",highlightthickness=1).grid(row=8,column=0,columnspan=3 )
reg21=Label(root,text="TELEPHONE NUMBER").grid(row=7,column=1 )
e6=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=8,column=1 )
reg22=Label(root,text="DMV CUSTOMER NUMBER/FEIN/SSN").grid(row=7,column=2 )
e7=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=8,column=2 )
reg23=Label(root,text="CO-OWNER'S FULL LEGAL NAME (last,first,mi,suffix)").grid(row=9,column=0,columnspan=3 )
e8=Entry(root,width=67,highlightbackground="black",highlightthickness=1).grid(row=10,column=0,columnspan=3 )
reg24=Label(root,text="TELEPHONE NUMBER").grid(row=9,column=1 )
e9=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=10,column=1 )
reg25=Label(root,text="DMV CUSTOMER NUMBER/FEIN/SSN").grid(row=9,column=2 )
e10=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=10,column=2 )
reg26=Label(root,text="Owners MUST provide residence/home/business address where requested this address\ncan not be a P.O Box. You must complete form ISO-01 if you want your address updated").grid(row=11,column=0 ,columnspan=3)
# reg27=Label(root,text="can not be a P.O Box. You must complete form ISO-01 if you would like your address updated").grid(row=12,column=0,columnspan=4 )
reg28=Label(root,text="RESIDENCE/BUSINESS JURISDICTION").grid(row=11,column=1 )
e11=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=12,column=1 )
reg29=Label(root,text="OWNER'S RESIDENCE/HOME/BUSINESS ADDRESS(Api &if applicable)").grid(row=13,column=0,columnspan=2 )
e12=Entry(root,width=63,highlightbackground="black",highlightthickness=1).grid(row=14,column=0 )
reg30=Label(root,text="CITY").grid(row=13,column=1 )
e13=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=14,column=1 )
reg31=Label(root,text="STATE").grid(row=13,column=2 )
e14=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=14,column=2 )
reg32=Label(root,text="ZIP CODE").grid(row=13,column=3 )
e15=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=14,column=3 )
reg33=Label(root,text="CO-OWNER'S RESIDENCE/HOME/BUSINESS ADDRESS(Api &if applicable)").grid(row=15,column=0,columnspan=2 )
e16=Entry(root,width=63,highlightbackground="black",highlightthickness=1).grid(row=16,column=0 )
reg34=Label(root,text="CITY").grid(row=15,column=1 )
e17=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=16,column=1 )
reg35=Label(root,text="STATE").grid(row=15,column=2 )
e18=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=16,column=2 )
reg36=Label(root,text="ZIP CODE").grid(row=15,column=3 )
e19=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=16,column=3 )
reg37=Label(root,text="OWNER EMAIL ADDRESS").grid(row=17,column=0,columnspan=3 )
e20=Entry(root,width=65,highlightbackground="black",highlightthickness=1).grid(row=18,column=0,columnspan=3 )
reg38=Label(root,text="CO-OWNER EMAIL ADDRESS").grid(row=17,column=1,columnspan=2 )
e21=Entry(root,width=65,highlightbackground="black",highlightthickness=1).grid(row=18,column=1,columnspan=2 )
mainheader1=Label(root,text="ADDITIONAL INFORMATION",font=('Helvetica', 18, 'bold'),borderwidth=1, relief="solid",bg="grey").grid(row=19,column=1,columnspan=2)
reg39=Label(root,text="LOCATION WHERE VEHICLE IS PRINCIPALLY GARAGED").grid(row=20,column=0,columnspan=3 )
reg40=Label(root,text="IF NEW LOCATION ENTER DATE CHANGED").grid(row=20,column=1 )
e22=Entry(root,width=40,highlightbackground="black",highlightthickness=1).grid(row=21,column=1 )
reg41=Label(root,text="Are any of the owners/leeses on active military duty or service").grid(row=20,column=3 ,columnspan=2)
reg42=Checkbutton(root,text="CITY",width=5).grid(row=22,column=0 )
reg43=Checkbutton(root,text="COUNTY",width=5).grid(row=22,column=1 )
reg45=Checkbutton(root,text="TOWN OF",width=7).grid(row=22,column=2 )
reg46=Checkbutton(root,text="YES").grid(row=21,column=3 )
reg46=Checkbutton(root,text="NO").grid(row=22,column=3 )
reg47=Label(root,text="IF YOU WOULD LIKE YOUR REGISTRATION RENEWALS SENT TO AN ADDRESS OTHER THAN YOUR RESIDENCE/BUSINESS ADDRESS ENTER IT BELOW").grid(row=23,column=0,columnspan=2 )
reg48=Label(root,text="REGISTRATION MAILING ADDRESS-OPTIONAL").grid(row=24,column=0,columnspan=2 )
e23=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=25,column=0,columnspan=2 )
reg49=Label(root,text="CITY").grid(row=24,column=1 )
e25=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=25,column=1 )
reg50=Label(root,text="STATE").grid(row=24,column=2 )
e26=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=25,column=2 )
reg51=Label(root,text="ZIP CODE").grid(row=24,column=3 )
e24=Entry(root,highlightbackground="black",highlightthickness=1).grid(row=25,column=3 )
root.mainloop()

# %%
#set2 ques4
import tkinter as t
from tkinter import messagebox
root =t.Tk()

l=t.Label(None,text="Form")
title=t.Label(None,text="TITLE")
Lastname=t.Label(None,text="LAST NAME")
Firstname= t.Label(None,text="First name")
Sharewith=t.Label(None,text="Share with")
businessno=t.Label(None,text="Business Number")
mobno=t.Label(None,text="Mobile Number")
emailadd=t.Label(None,text="Email Address")
DateofArrival=t.Label(None,text="Date of Arrival")
DateofDeparture=t.Label(None,text="Date of Departure")
Nameoncredit=t.Label(None,text="Name on Credit Card")
Creditno=t.Label(None,text="Credit card Number")
Expirydate=t.Label(None,text="Expiry Date")
cvv=t.Label(None,text="CVV Number")
paymentmethod=t.Label(None,text="Payment Method")

titlee=t.Entry(None,text="TITLE")
Lastnamee=t.Entry(None,text="LAST NAME")
Firstnamee= t.Entry(None,text="First name")
Sharewithe=t.Entry(None,text="Share with")
businessnoe=t.Entry(None,text="Business Number")
mobnoe=t.Entry(None,text="Mobile Number")
emailadde=t.Entry(None,text="Email Address")
DateofArrivale=t.Entry(None,text="Date of Arrival")
DateofDeparturee=t.Entry(None,text="Date of Departure")
Nameoncredite=t.Entry(None,text="Name on Credit Card")
Creditnoe=t.Entry(None,text="Credit card Number")
Expirydatee=t.Entry(None,text="Expiry Date")
cvve=t.Entry(None,text="CVV Number")
v = t.IntVar()

l.grid(row=0,column=6)
title.grid(row=2,column=5)
titlee.grid(row=2,column=7)
Lastname.grid(row=5,column=5)
Lastnamee.grid(row=5,column=7)
Firstname.grid(row=8,column=5)
Firstnamee.grid(row=8,column=7)
Sharewith.grid(row=11,column=5)
Sharewithe.grid(row=11,column=7)
businessno.grid(row=14,column=5)
businessnoe.grid(row=14,column=7)
mobno.grid(row=17,column=5)
mobnoe.grid(row=17,column=7)
emailadd.grid(row=20,column=5)
emailadde.grid(row=20,column=7)
DateofArrival.grid(row=23,column=5)
DateofArrivale.grid(row=23,column=7)
DateofDeparture.grid(row=26,column=5)
DateofDeparturee.grid(row=26,column=7)
Nameoncredit.grid(row=29,column=5)
Nameoncredite.grid(row=29,column=7)
Creditno.grid(row=32,column=5)
Creditnoe.grid(row=32,column=7)
Expirydate.grid(row=35,column=5)
Expirydatee.grid(row=35,column=7)
cvv.grid(row=38,column=5)
cvve.grid(row=38,column=7)
paymentmethod.grid(row=40,column=5)
CreditCard =t.Radiobutton(root,text = "Credit Card", variable = v, value =1)
CreditCard.grid(row=40, column = 7)
CreditCard =t.Radiobutton(root,text = "Direct Bank Transfer", variable = v, value =2)
CreditCard.grid(row=40, column =8)
def smit():
        messagebox.showinfo("Submitted", "Your Data has been submitted!!")
submit = t.Button(root, text = 'Submit', bd = '5', command = smit).grid(row=42,column=7)

t.mainloop()
