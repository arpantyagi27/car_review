# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/arpan/Downloads/train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70128 entries, 0 to 70127
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    70128 non-null  int64
#  1   date      70128 non-null  object
#  2   country   70128 non-null  object
#  3   store     70128 non-null  object
#  4   product   70128 non-null  object
#  5   num_sold  70128 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 3.2+ MB

# %%
data.head()
# Out:
#    row_id        date  country       store                           product  \
# 0       0  2017-01-01  Belgium  KaggleMart        Kaggle Advanced Techniques
# 1       1  2017-01-01  Belgium  KaggleMart            Kaggle Getting Started
# 2       2  2017-01-01  Belgium  KaggleMart                Kaggle Recipe Book
# 3       3  2017-01-01  Belgium  KaggleMart  Kaggle for Kids: One Smart Goose
# 4       4  2017-01-01  Belgium  KaggleRama        Kaggle Advanced Techniques
#
#    num_sold
# 0       663
# 1       615
# 2       480
# 3       710
# 4       240

# %%
data.describe()
# Out:
#              row_id      num_sold
# count  70128.000000  70128.000000
# mean   35063.500000    194.296986
# std    20244.354176    126.893874
# min        0.000000     19.000000
# 25%    17531.750000     95.000000
# 50%    35063.500000    148.000000
# 75%    52595.250000    283.000000
# max    70127.000000    986.000000

# %%
data.isnull().sum()
# Out:
# row_id      0
# date        0
# country     0
# store       0
# product     0
# num_sold    0
# dtype: int64

# %%
data = data.drop('row_id', axis=1)
data.head()
# Out:
#          date  country       store                           product  num_sold
# 0  2017-01-01  Belgium  KaggleMart        Kaggle Advanced Techniques       663
# 1  2017-01-01  Belgium  KaggleMart            Kaggle Getting Started       615
# 2  2017-01-01  Belgium  KaggleMart                Kaggle Recipe Book       480
# 3  2017-01-01  Belgium  KaggleMart  Kaggle for Kids: One Smart Goose       710
# 4  2017-01-01  Belgium  KaggleRama        Kaggle Advanced Techniques       240

# %%
data.date = pd.to_datetime(data.date)
data['Month'] = data.date.dt.month_name()
data['Date'] = data.date.dt.day
data['Day'] = data.date.dt.day_name()
data['Year'] = data.date.dt.year
data.head()
# Out:
#         date  country       store                           product  num_sold  \
# 0 2017-01-01  Belgium  KaggleMart        Kaggle Advanced Techniques       663
# 1 2017-01-01  Belgium  KaggleMart            Kaggle Getting Started       615
# 2 2017-01-01  Belgium  KaggleMart                Kaggle Recipe Book       480
# 3 2017-01-01  Belgium  KaggleMart  Kaggle for Kids: One Smart Goose       710
# 4 2017-01-01  Belgium  KaggleRama        Kaggle Advanced Techniques       240
#
#      Month  Date     Day  Year
# 0  January     1  Sunday  2017
# 1  January     1  Sunday  2017
# 2  January     1  Sunday  2017
# 3  January     1  Sunday  2017
# 4  January     1  Sunday  2017

# %%
org = data.copy()
salecountry = org.groupby('country')['num_sold'].sum()
salecountry.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
salestore = org.groupby('store')['num_sold'].sum()
salestore.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='store'>

# %%
sns.barplot(x='country', y='num_sold', data=org, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='country', ylabel='num_sold'>

# %%
salepro= org.groupby('product')['num_sold'].sum()
salepro.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product'>

# %%
sns.barplot(x='product', y='num_sold', data=org, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
saleyear= org.groupby('Year')['num_sold'].sum()
saleyear.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x='Year', y='num_sold', data=org, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
salemonth= org.groupby('Month')['num_sold'].sum()
salemonth.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.barplot(x='Month', y='num_sold', data=org, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='num_sold'>

# %%
saleday= org.groupby('Day')['num_sold'].sum()
saleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
sns.barplot(x='Day', y='num_sold', data=org, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
data.country.value_counts()
# Out:
# Belgium    11688
# France     11688
# Germany    11688
# Italy      11688
# Poland     11688
# Spain      11688
# Name: country, dtype: int64

# %%
sns.barplot(x='Day', y='num_sold', data=Belgium, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
Belgium=data[data.country == 'Belgium']
Bsaleday= Belgium.groupby('Day')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
Bsalemonth= Belgium.groupby('Month')['num_sold'].sum()
Bsalemonth.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.barplot(x='Month', y='num_sold', data=Belgium, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='num_sold'>

# %%
Bsaley= Belgium.groupby('Year')['num_sold'].sum()
Bsaley.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x='Year', y='num_sold', data=Belgium, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
Bsalep= Belgium.groupby('product')['num_sold'].sum()
Bsalep.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product'>

# %%
sns.barplot(x='product', y='num_sold', data=Belgium, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
France=data[data.country == 'France']
fsaleday= France.groupby('Day')['num_sold'].sum()

fsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
sns.barplot(x='Day', y='num_sold', data=France, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
fsalem=France.groupby('Month')['num_sold'].sum()
fsalem.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.barplot(x='Month', y='num_sold', data=France, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='num_sold'>

# %%
fsalem=France.groupby('Year')['num_sold'].sum()
fsalem.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x='Year', y='num_sold', data=France, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
Bsaleday= France.groupby('product')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product'>

# %%
sns.barplot(x='product', y='num_sold', data=France, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
Germany=data[data.country == 'Germany']
Bsaleday= Germany.groupby('Day')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
Bsaleday= Germany.groupby('Month')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.barplot(x='Day', y='num_sold', data=Germany, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
Bsaleday= Germany.groupby('Year')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x='Year', y='num_sold', data=Germany, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
Bsaleday= Germany.groupby('product')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product'>

# %%
sns.barplot(x='product', y='num_sold', data=Germany, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
Italy=data[data.country == 'Italy']
Bsaleday= Itlay.groupby('Day')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
sns.barplot(x='Day', y='num_sold', data=Italy, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
Bsaleday= Itlay.groupby('Month')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.barplot(x='Month', y='num_sold', data=Italy, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='num_sold'>

# %%
Bsaleday= Itlay.groupby('Year')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x='Year', y='num_sold', data=Italy, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
Bsaleday= Itlay.groupby('product')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product'>

# %%
sns.barplot(x='product', y='num_sold', data=Italy, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
Poland=data[data.country == 'Poland']
Bsaleday=Poland.groupby('Day')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
sns.barplot(x='Day', y='num_sold', data=Poland, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>

# %%
Bsaleday=Poland.groupby('Month')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.barplot(x='Month', y='num_sold', data=Poland, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='num_sold'>

# %%
Bsaleday=Poland.groupby('Year')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x='Year', y='num_sold', data=Poland, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
Bsaleday=Poland.groupby('product')['num_sold'].sum()
Bsaleday.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product'>

# %%
sns.barplot(x='product', y='num_sold', data=Poland, color='blue', hue='store')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
sns.barplot(x='product', y='num_sold', data=data, color='blue', hue='Year')
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
labels = data['product'].value_counts().index
sizes = [data.groupby('product')['num_sold'].sum()[0], data.groupby('product')['num_sold'].sum()[1], data.groupby('product')['num_sold'].sum()[2], data.groupby('product')['num_sold'].sum()[3]]
explode = (0, 0, 0.1, 0.05)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
shadow=True, startangle=90)
ax1.axis('equal')
plt.title('Sales per product')
plt.show()

# %%
years=pd.DataFrame(data.groupby('Year')['num_sold'].sum())
years.reset_index(inplace=True)
labels = years.Year.value_counts().index
sizes = [years.num_sold[0],years.num_sold[1],years.num_sold[2],years.num_sold[3]]
explode = (0.1,0, 0,0.05)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
shadow=True, startangle=90)
ax1.axis('equal')
plt.title('Percentage of number of products sold per year')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.lineplot(x='Year',y='num_sold',data=data,hue='product')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='num_sold'>

# %%
plt.figure(figsize=(15,15))
sns.lineplot(x='Day',y='num_sold',data=data,hue='product')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='num_sold'>
